# %%
# Assignment 9: Data Visualization II 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')

print("First 5 Rows:\n", df.head())
# Out:
# First 5 Rows:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(x='sex', y='age', hue='survived', data=df)

plt.title("Age Distribution by Gender and Survival")
plt.xlabel("Gender")
plt.ylabel("Age")

plt.show()

# %%
# ✅ Theory

# Data Visualization II focuses on analyzing data distribution and detecting outliers using boxplots. 
# A boxplot is a statistical graph that represents data using quartiles, median, and whiskers.

# The boxplot displays the spread and skewness of the data along with potential outliers. In this assignment, the Titanic dataset is used to compare the age distribution of passengers based on gender and survival status.

# The “hue” parameter is used to include an additional categorical variable in the visualization. This helps in comparing multiple categories simultaneously.

# Boxplots are useful for understanding variability, identifying unusual observations, and comparing distributions between groups.

# 🔹 Key Points to Write
# Boxplot visualization
# Quartiles and median
# Outlier detection
# Comparison of categories
# Data distribution analysis

# ✅ Advantages
# Detects outliers easily
# Shows spread of data clearly
# Useful for comparison
# Compact statistical representation

# ❌ Disadvantages
# Does not show exact data values
# Difficult for beginners to interpret
# Limited detail about distribution shape

# 📌 Applications
# Exploratory data analysis
# Statistical analysis
# Research studies
# Business intelligence
