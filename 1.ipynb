# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("heart_disease.csv")

# %%
print("Dataset Shape:", df.shape)
print("\nFirst 5 Rows:\n", df.head())

print("\nMissing Values:\n", df.isnull().sum())

print("\nStatistical Summary:\n", df.describe())

print("\nData Types:\n")
print(df.info())
# Out:
# Dataset Shape: (1025, 14)
#
# First 5 Rows:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Missing Values:
#  age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
#
# Statistical Summary:
# ...

# %%
df['sex'] = df['sex'].astype('category')
print("\nUpdated Data Types:\n", df.dtypes)
# Out:
# Updated Data Types:
#  age            int64
# sex         category
# cp             int64
# trestbps       int64
# chol           int64
# fbs            int64
# restecg        int64
# thalach        int64
# exang          int64
# oldpeak      float64
# slope          int64
# ca             int64
# thal           int64
# target         int64
# dtype: object

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[numeric_cols] = (df[numeric_cols] - df[numeric_cols].min()) / (df[numeric_cols].max() - df[numeric_cols].min())
print("\nAfter Normalization:\n", df.head())

df['sex'] = df['sex'].cat.codes
print("\nAfter Encoding:\n", df.head())
# Out:
# After Normalization:
#          age sex   cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.479167   1  0.0  0.292453  0.196347  0.0      0.5  0.740458    0.0
# 1  0.500000   1  0.0  0.433962  0.175799  1.0      0.0  0.641221    1.0
# 2  0.854167   1  0.0  0.481132  0.109589  0.0      0.5  0.412214    1.0
# 3  0.666667   1  0.0  0.509434  0.175799  0.0      0.5  0.687023    0.0
# 4  0.687500   0  0.0  0.415094  0.383562  1.0      0.5  0.267176    0.0
#
#     oldpeak  slope    ca      thal  target
# 0  0.161290    1.0  0.50  1.000000     0.0
# 1  0.500000    0.0  0.00  1.000000     0.0
# 2  0.419355    0.0  0.00  1.000000     0.0
# 3  0.000000    1.0  0.25  1.000000     0.0
# 4  0.306452    0.5  0.75  0.666667     0.0
#
# After Encoding:
#          age  sex   cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.479167    1  0.0  0.292453  0.196347  0.0      0.5  0.740458    0.0
# 1  0.500000    1  0.0  0.433962  0.175799  1.0      0.0  0.641221    1.0
# ...

# %%
# ✅ Theory

# Data wrangling is the process of cleaning, transforming, and organizing raw data into a usable format 
# for analysis. In real-world scenarios, data is often incomplete, inconsistent, and unstructured, making it unsuitable for direct analysis. Therefore, data wrangling plays a crucial role in preparing data for further processing.

# The first step involves loading the dataset into a structured format such as a pandas DataFrame. 
# After loading, initial exploration is performed using functions like info() and describe() to understand data types, missing values, and statistical properties.

# Next, missing values are identified and handled appropriately. Data formatting is then performed by 
# correcting data types such as converting numerical or categorical variables into proper formats. 
# This ensures consistency and correctness in the dataset.

# Normalization is applied to scale numerical values to a common range, preventing dominance of larger values.
# Finally, categorical variables are converted into numerical form using techniques like label encoding 
# or one-hot encoding. This step is essential for machine learning models which require numeric input.

# Overall, data wrangling improves data quality and ensures reliable analysis.

# 🔹 Key Points to Write
# Data cleaning and transformation
# Handling missing values
# Data type correction
# Normalization
# Categorical to numerical conversion

# ✅ Advantages
# Improves data quality
# Ensures accurate analysis
# Prepares data for ML models
# Handles inconsistencies

# ❌ Disadvantages
# Time-consuming process
# Requires domain knowledge
# Risk of incorrect transformation

# 📌 Applications
# Data preprocessing
# Machine learning pipelines
# Business analytics
# Data integration
